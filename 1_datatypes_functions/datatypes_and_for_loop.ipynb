# %%
print("hellow world")
# Out:
# hellow world

# %%
print("how are you")
# Out:
# how are you

# %%
rev = [50,60,55]
exp = [10,30,35]

# %%
for rev in rev:
    print("revs is ",str(rev))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 for rev in rev:
#       2     print("revs is ",str(rev))
#
# TypeError: 'int' object is not iterable
